# %% [markdown]
# Desafio -Imersão de dados 4 Aula 1 - José Alexandre
# LinkedIn: https://www.linkedin.com/in/jos%C3%A9-alexandre-98291238/
#
#
# Desafios:
#
# 1 - Realizar a média da metragem para cada um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
import pandas as pd
url = "https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv"
dados = pd.read_csv(url)

# %%
dados.head()
# Out:
#                               Rua              Bairro     Cidade  Metragem  \
# 0           Avenida Itacira, 255    Planalto Paulista  São Paulo      1000
# 1  Rua Aurelia Perez Alvarez, 42   Jardim dos Estados  São Paulo       496
# 2                 Rua Alba Valdez     Jardim Reimberg  São Paulo       125
# 3                             NaN      Jardim Morumbi  São Paulo       310
# 4        Rua Tobias Barreto, 195                Mooca  São Paulo       100
#
#    Quartos  Banheiros  Vagas         Valor
# 0        4          8      6  R$ 7.000.000
# 1        4          4      4  R$ 3.700.000
# 2        4          3      2    R$ 380.000
# 3        3          2      4    R$ 685.000
# 4        3          2      2    R$ 540.000

# %%
dados.sample(10)
# Out:
#                                 Rua                 Bairro     Cidade  \
# 6999               Rua Rocha Galvão       Jardim da Glória  São Paulo
# 6949       Rua Ferreira do Alentejo       Jardim Caravelas  São Paulo
# 8698                            NaN     Vila Regente Feijó  São Paulo
# 6522  Rua Doutor Sales Gomes Júnior       Vila Paulo Silas  São Paulo
# 4342             Rua Cayowaá, 1755                  Sumaré  São Paulo
# 4790                            NaN        Jardim Paulista  São Paulo
# 302                 Rua Teviot, 50     Vila Nova Conceição  São Paulo
# 255          Rua Maestro Elias Lobo        Jardim Paulista  São Paulo
# 7213                            NaN  Vila Brasílio Machado  São Paulo
# 2986            Rua Francisco Farel   Jardim das Bandeiras  São Paulo
#
#       Metragem  Quartos  Banheiros  Vagas         Valor
# 6999       305        3          3      4  R$ 1.085.000
# 6949       240        4          4      3  R$ 1.535.000
# ...

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10008 entries, 0 to 10007
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Rua        6574 non-null   object
#  1   Bairro     9996 non-null   object
#  2   Cidade     10008 non-null  object
#  3   Metragem   10008 non-null  int64
#  4   Quartos    10008 non-null  int64
#  5   Banheiros  10008 non-null  int64
#  6   Vagas      10008 non-null  int64
#  7   Valor      10008 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 625.6+ KB

# %%
dados["Bairro"][6522]
# Out:
# 'Vila Paulo Silas'

# %%
dados.Metragem.mean()
# Out:
# 442.30065947242207

# %%
dados["Metragem"].mean()
# Out:
# 442.30065947242207

# %%
sum((dados["Bairro"] == "Vila Mariana"))
# Out:
# 184

# %%
tem_imoveis_vila =( dados["Bairro"] == "Vila Mariana")
tem_imoveis_vila
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10003    False
# 10004    False
# 10005    False
# 10006    False
# 10007    False
# Name: Bairro, Length: 10008, dtype: bool

# %%
imoveis_vila_mariana = dados[tem_imoveis_vila]
imoveis_vila_mariana
# Out:
#                                Rua        Bairro     Cidade  Metragem  \
# 100               Rua Pero Correia  Vila Mariana  São Paulo       250
# 120   Praça Doutor Carvalho Franco  Vila Mariana  São Paulo       250
# 155     Rua Professor João Marinho  Vila Mariana  São Paulo       170
# 160                            NaN  Vila Mariana  São Paulo       228
# 334         Rua Pero Correia, 892   Vila Mariana  São Paulo       350
# ...                            ...           ...        ...       ...
# 9645               Rua Sousa Ramos  Vila Mariana  São Paulo       285
# 9701             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9737             Rua Benito Juarez  Vila Mariana  São Paulo       171
# 9807                           NaN  Vila Mariana  São Paulo       275
# 9852              Rua França Pinto  Vila Mariana  São Paulo       280
#
#       Quartos  Banheiros  Vagas         Valor
# 100         3          3      1  R$ 1.350.000
# ...

# %%
imoveis_vila_mariana["Metragem"].mean()
# Out:
# 233.6195652173913

# %%
dados["Bairro"].value_counts()
# Out:
# Alto de Pinheiros     409
# Jardim Guedala        403
# Jardim Paulista       309
# Brooklin Paulista     247
# Jardim Europa         240
#                      ...
# Jardim das Imbuias      1
# Vila Represa            1
# Vila Nancy              1
# Sítio Represa           1
# Vila Invernada          1
# Name: Bairro, Length: 701, dtype: int64

# %%
n_imoveis_bairro = dados["Bairro"].value_counts()
n_imoveis_bairro.head(10).plot.bar()

# %% [markdown]
# Desafios:
#
# 1 - Realizar a média da metragem para cada um dos bairros (Paulo)
#
# 2 - 2 formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)
#
# 3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)
#
# 4 - Pegar outros estatísticas dos dados, média, mediana, mim, max (Vivi)
#
# 5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %% [markdown]
# Questão1 - Realizar a média da metragem para cada um dos bairros. (Proposto pelo Paulo).

# %%
bairros = dados['Bairro'].values # Nome dos bairros.
dict_media_metragem = {}

for bairro in bairros:
  media_metragem = dados.loc[dados['Bairro'] == bairro, 'Metragem'].mean() # Calcula a média da metragem de acordo com o nome do bairro.
  dict_media_metragem[bairro] = media_metragem # Adiciona a média ao dicionário.

dict_media_metragem
# Out:
# {'Aclimação': 253.0568181818182,
#  'Alto da Boa Vista': 418.875,
#  'Alto da Lapa': 294.33720930232556,
#  'Alto da Mooca': 270.05,
#  'Alto de Pinheiros': 433.4449877750611,
#  'Aricanduva': 278.0,
#  'Balneário Mar Paulista': 250.0,
#  'Barra Funda': 135.44444444444446,
#  'Barro Branco (Zona Norte)': 489.0,
#  'Bela Aliança': 345.4761904761905,
#  'Bela Vista': 190.0,
#  'Belenzinho': 215.69230769230768,
#  'Boaçava': 512.0260869565218,
#  'Bom Retiro': 336.5,
#  'Bortolândia': 151.66666666666666,
#  'Bosque da Saúde': 247.59259259259258,
#  'Brasilândia': 83.75,
#  'Brooklin': 339.4166666666667,
#  'Brooklin Novo': 290.3,
#  'Brooklin Paulista': 323.6761133603239,
#  'Brás': 181.25,
#  'Burgo Paulista': 150.0,
#  'Butantã': 381.45,
#  'Cambuci': 203.63333333333333,
#  'Campininha': 133.0,
#  'Campo Belo': 279.6917808219178,
#  'Campo Grande': 163.33333333333334,
#  'Campos Elíseos': 530.0,
#  'Canindé': 107.5,
#  'Capela do Socorro': 120.0,
#  'Capão Redondo': 125.0,
# ...

# %% [markdown]
# Questão2 - Duas formas de selecionar os dados por bairro (consultar os métodos na documentação do Pandas). (Proposto pelo Thiago).
#
# 2 formas de consultar dados por bairro:
#
# .loc[], filtra usando rótulos.
#
# .iloc[], filtra usando index.
#
# exemplos:

# %%
dados.loc[dados['Bairro'] == 'Vila Ema'] # Filtra apenas os valores do bairro Vila Ema.
# Out:
#                         Rua    Bairro     Cidade  Metragem  Quartos  \
# 401                     NaN  Vila Ema  São Paulo        88        2
# 2788                    NaN  Vila Ema  São Paulo       160        3
# 5539     Rua Herwis, , 388   Vila Ema  São Paulo       160        3
# 5674     Rua Herwis, , 388   Vila Ema  São Paulo       165        3
# 6189     Rua Herwis, , 388   Vila Ema  São Paulo       165        3
# 7864  Travessa Pacheco Lima  Vila Ema  São Paulo       106        3
# 9147     Rua Augusto Fetzer  Vila Ema  São Paulo       150        3
#
#       Banheiros  Vagas       Valor
# 401           2      3  R$ 470.000
# 2788          2      1  R$ 421.000
# 5539          2      4  R$ 462.770
# 5674          2      4  R$ 462.770
# 6189          2      4  R$ 462.770
# 7864          2      1  R$ 420.000
# 9147          3      3  R$ 695.000

# %% [markdown]
# Questão3 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, assim como tentar colocar alguma conclusão.(Proposto pelo Thiago).

# %%
moradia_bairros = dados['Bairro'].value_counts().head(5) # Filtra os 5 bairros com mais moradias disponíveis.
demais_bairros = dados['Bairro'].value_counts().sum() - moradia_bairros.sum() # Conta as moradias restantes

moradia_bairros['Outros bairros'] = demais_bairros

moradia_bairros.plot(kind='pie', autopct='%1.1f%%', fontsize=8, figsize=(7, 7)) # autopct='%1.1f%% mostra o valor em porcentagem no gráfico.

# %% [markdown]
# Questão4 4 - Pegar outras estatísticas dos dados (como média, mediana, mim, max).(Proposto pela Vivian).
#
# Relatório estatístico básico de dados com a função describe().

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000

# %% [markdown]
# 5 - Descobrir quais são os bairros que não tem nome de rua. (Proposto pela Vivian).

# %%
# bairros que não possuem rua.
bairros_sem_rua = []

for bairro in dados['Bairro'].values:
  nao_nulos = dados.loc[dados['Bairro'] == bairro, 'Rua'].notnull().sum() # conta os não nulos.
  if nao_nulos == 0: # Se a quantidade de não nulos for 0, adiciona a lista.
    bairros_sem_rua.append(bairro)

bairros_sem_rua
# Out:
# ['Vila Aparecida',
#  'Vila Sabrina',
#  'Jardim Camargo Novo',
#  'Jardim Planalto',
#  'Jardim das Camélias',
#  'Jardim Célia (Zona Sul)',
#  'Parque Guarani',
#  'Conjunto Residencial Vista Verde',
#  'Jardim Santo Elias',
#  'Vila Londrina',
#  'Vila Londrina',
#  'Vila Cláudia',
#  'Vila Cláudia',
#  'Vila Sílvia',
#  'Vila Sílvia',
#  'Vila Sílvia',
#  'Vila Sílvia',
#  'Vila Gea',
#  'Vila Lageado',
#  'Vila Perus',
#  'Jardim Satélite',
#  'Vila Lageado',
#  'Vila Perus',
#  'Jardim Satélite',
#  'Vila São Francisco',
#  'Vila São Francisco',
#  'Vila Salete',
#  'Vila Nova Caledonia',
#  'Vila Carbone',
#  'Vila Nova Caledonia',
#  'Chácara Tatuapé',
#  'Parque Residencial Oratorio',
#  'Parque Residencial Oratorio',
#  'Jardim Santa Cruz (Campo Grande)',
#  'Cidade Centenário',
#  'Jardim Petropolis',
#  'Vila Califórnia(Zona Sul)',
#  'Vila Mafra',
#  'Jardim Rizzo',
#  'Vila Califórnia(Zona Sul)',
#  'Vila Mafra',
#  'Vila Califórnia(Zona Sul)',
#  'Vila Mafra',
# ...
